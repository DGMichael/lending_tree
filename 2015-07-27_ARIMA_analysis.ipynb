# %%
ls
# Out:
# 2015-07-14_lending_club.ipynb
# 2015-07-23_multiple_regression.ipynb
# 2015-07-24_Multiple_Regression_2.0.ipynb
# 2015-07-27_ARIMA_analysis.ipynb
# LoanStats3b.csv*
# box_requested.png
# chi_square.py
# hist_requested.png
# linear_regression.ipynb
# linear_regression.py
# loansData_clean.csv
# logistic_regression.py.ipynb
# prob_lending_club.py
# qqplot_requested.png

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load dataframe:
#df = pd.read_csv("LoanStats3b.csv",header = 1, low_memory=False)
df.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  10127816   11979581      24000        24000            24000   36 months
# 1  10224583   12086734      11100        11100            11100   36 months
# 2  10148122   11999781      12000        12000            12000   36 months
# 3  10148818   12000415      15000        15000            15000   36 months
# 4  10149526   12001069      27600        27600            27600   60 months
#
#   int_rate  installment grade sub_grade      ...       recoveries  \
# 0   13.53%       814.80     B        B5      ...                0
# 1   14.98%       384.68     C        C3      ...                0
# 2    7.62%       373.94     A        A3      ...                0
# 3   14.47%       516.10     C        C2      ...                0
# 4   19.97%       730.78     D        D5      ...                0
#
#   collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d  \
# 0                       0     Jun-2015           814.80     Aug-2015
# 1                       0     Jun-2015           384.68     Aug-2015
# 2                       0     Jun-2015           373.94     Aug-2015
# 3                       0     May-2014         14150.76          NaN
# 4                       0     Jun-2015           730.78     Aug-2015
#
#   last_credit_pull_d collections_12_mths_ex_med mths_since_last_major_derog  \
# 0           Jun-2015                          0                         NaN
# 1           Jun-2015                          0                          16
# 2           Jun-2015                          0                         NaN
# 3           Jun-2015                          0                         NaN
# 4           Jun-2015                          0                           7
#
#   policy_code issue_d_format
# 0           1     2013-12-27
# 1           1     2013-12-27
# 2           1     2013-12-27
# 3           1     2013-12-27
# 4           1     2013-12-27
#
# [5 rows x 53 columns]

# %%
df["issue_d_format"] = pd.to_datetime(df["issue_d"])

# %%
df.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  10127816   11979581      24000        24000            24000   36 months
# 1  10224583   12086734      11100        11100            11100   36 months
# 2  10148122   11999781      12000        12000            12000   36 months
# 3  10148818   12000415      15000        15000            15000   36 months
# 4  10149526   12001069      27600        27600            27600   60 months
#
#   int_rate  installment grade sub_grade      ...       recoveries  \
# 0   13.53%       814.80     B        B5      ...                0
# 1   14.98%       384.68     C        C3      ...                0
# 2    7.62%       373.94     A        A3      ...                0
# 3   14.47%       516.10     C        C2      ...                0
# 4   19.97%       730.78     D        D5      ...                0
#
#   collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d  \
# 0                       0     Jun-2015           814.80     Aug-2015
# 1                       0     Jun-2015           384.68     Aug-2015
# 2                       0     Jun-2015           373.94     Aug-2015
# 3                       0     May-2014         14150.76          NaN
# 4                       0     Jun-2015           730.78     Aug-2015
#
#   last_credit_pull_d collections_12_mths_ex_med mths_since_last_major_derog  \
# 0           Jun-2015                          0                         NaN
# 1           Jun-2015                          0                          16
# 2           Jun-2015                          0                         NaN
# 3           Jun-2015                          0                         NaN
# 4           Jun-2015                          0                           7
#
#   policy_code issue_d_format
# 0           1     2013-12-27
# 1           1     2013-12-27
# 2           1     2013-12-27
# 3           1     2013-12-27
# 4           1     2013-12-27
#
# [5 rows x 53 columns]

# %%
dfts = df.set_index("issue_d_format")
year_month_summary = dfts.groupby(lambda x: x.year * 100 + x.month).count()
loan_count_summary = year_month_summary['issue_d']

# %%
loan_count_summary.plot()

# %%
import statsmodels

# %%
statsmodels.api.graphics.tsa.plot_acf(loan_count_summary)

# %%
statsmodels.api.graphics.tsa.plot_pacf(loan_count_summary)
